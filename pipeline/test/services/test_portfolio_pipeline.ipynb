# %% [markdown]
# # 🧪 Test Portfolio Pipeline - Strix System
#
# Este notebook ejecuta y prueba el pipeline de procesamiento de portfolios del sistema Strix desde el proyecto `pipeline` en Visual Studio Code.
#
# ## 📋 Requisitos:
# - Estar ejecutando desde el directorio `pipeline`
# - Tener configurado el archivo `.env` con las credenciales
# - Tener los módulos `core` y `security` instalados en modo editable o accesibles

# %%
# Celda 1: Configuración de rutas y verificación
import sys
import os

# Obtener la ruta raíz del proyecto
current_dir = os.getcwd()
print(f"🔹 Directorio actual: {current_dir}")

# Buscar la raíz del proyecto (donde está el venv)
def find_project_root(start_dir):
    """Busca la raíz del proyecto subiendo directorios hasta encontrar 'venv'"""
    current = start_dir
    while current != os.path.dirname(current):  # Hasta llegar a la raíz del sistema
        if os.path.exists(os.path.join(current, 'venv')):
            return current
        current = os.path.dirname(current)
    return None

project_root = find_project_root(current_dir)
print(f"🔹 Raíz del proyecto encontrada: {project_root}")

# Agregar la raíz del proyecto al sys.path si no está
if project_root and project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"✅ Raíz del proyecto agregada a sys.path")

# Verificar que los módulos ahora son importables
def test_imports():
    print("\n🔍 Probando imports...")
    
    try:
        import core
        print(f"✅ core importado desde: {core.__file__}")
    except ImportError as e:
        print(f"❌ core: {e}")
    
    try:
        import security  
        print(f"✅ security importado desde: {security.__file__}")
    except ImportError as e:
        print(f"❌ security: {e}")
        
    try:
        import pipeline
        print(f"✅ pipeline importado desde: {pipeline.__file__}")
    except ImportError as e:
        print(f"❌ pipeline: {e}")

test_imports()

# Probar imports específicos que necesitamos
print("\n🔍 Probando imports específicos...")

try:
    from security.services.health_check import health_check
    print("✅ health_check importado correctamente")
    health_available = True
except ImportError as e:
    print(f"❌ health_check: {e}")
    health_available = False

try:
    from pipeline.services.portfolio_pipeline import PortfolioPipelineProcessor
    print("✅ PortfolioPipelineProcessor importado correctamente")
    pipeline_available = True
except ImportError as e:
    print(f"❌ PortfolioPipelineProcessor: {e}")
    pipeline_available = False

try:
    from core.infraestructure.uow.sqlalchemy_uow import SQLAlchemyUnitOfWork
    print("✅ SQLAlchemyUnitOfWork importado correctamente")
    uow_available = True
except ImportError as e:
    print(f"❌ SQLAlchemyUnitOfWork: {e}")
    uow_available = False

print(f"\n📊 Estado de módulos disponibles:")
print(f"   health_check: {'✅' if health_available else '❌'}")
print(f"   PortfolioPipelineProcessor: {'✅' if pipeline_available else '❌'}")
print(f"   SQLAlchemyUnitOfWork: {'✅' if uow_available else '❌'}")

# Verificar rutas actuales en sys.path
print(f"\n🛤️ Primeras 5 rutas en sys.path:")
for i, path in enumerate(sys.path[:5]):
    print(f"   {i+1}. {path}")
# Out:
# 🔹 Directorio actual: c:\code\strix-system\pipeline\test\services
# 🔹 Raíz del proyecto encontrada: c:\code\strix-system
# ✅ Raíz del proyecto agregada a sys.path
#
# 🔍 Probando imports...
# ✅ core importado desde: c:\code\strix-system\core\__init__.py
# ✅ security importado desde: c:\code\strix-system\security\__init__.py
# ✅ pipeline importado desde: c:\code\strix-system\pipeline\__init__.py
#
# 🔍 Probando imports específicos...
# ✅ health_check importado correctamente
# ✅ PortfolioPipelineProcessor importado correctamente
# ✅ SQLAlchemyUnitOfWork importado correctamente
#
# 📊 Estado de módulos disponibles:
#    health_check: ✅
#    PortfolioPipelineProcessor: ✅
#    SQLAlchemyUnitOfWork: ✅
#
# 🛤️ Primeras 5 rutas en sys.path:
#    1. c:\code\strix-system
#    2. c:\code\strix-system\pipeline\test
#    3. C:\Users\gsolomita\AppData\Local\Programs\Python\Python311\python311.zip
#    4. C:\Users\gsolomita\AppData\Local\Programs\Python\Python311\DLLs
#    5. C:\Users\gsolomita\AppData\Local\Programs\Python\Python311\Lib

# %%
# EJECUTAR ESTA CELDA PRIMERO - Arreglo de rutas
import sys
import os

# Ir 3 niveles arriba desde pipeline/test/services hasta la raíz
current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, '..', '..', '..'))

print(f"📂 Directorio actual: {current_dir}")
print(f"🏠 Raíz del proyecto: {project_root}")

# Verificar que existe el venv en la raíz
venv_path = os.path.join(project_root, 'venv')
if os.path.exists(venv_path):
    print(f"✅ Estructura correcta - venv encontrado en: {venv_path}")
else:
    print(f"❌ No se encontró venv en: {venv_path}")

# Agregar la raíz al sys.path
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"✅ Raíz agregada a sys.path")

# Cambiar el directorio de trabajo a la raíz
os.chdir(project_root)
print(f"✅ Directorio de trabajo cambiado a: {os.getcwd()}")

# Verificar imports
print("\n🧪 Verificando imports...")
try:
    from security.services.health_check import health_check
    print("✅ health_check - OK")
except Exception as e:
    print(f"❌ health_check - {e}")

try:
    from pipeline.services.portfolio_pipeline import PortfolioPipelineProcessor  
    print("✅ PortfolioPipelineProcessor - OK")
except Exception as e:
    print(f"❌ PortfolioPipelineProcessor - {e}")

try:
    from core.infraestructure.uow.sqlalchemy_uow import SQLAlchemyUnitOfWork
    print("✅ SQLAlchemyUnitOfWork - OK")
except Exception as e:
    print(f"❌ SQLAlchemyUnitOfWork - {e}")

print("\n🎯 ¡Configuración completada! Ahora puedes ejecutar el resto del notebook.")
# Out:
# 📂 Directorio actual: c:\code\strix-system\pipeline\test\services
# 🏠 Raíz del proyecto: c:\code\strix-system
# ✅ Estructura correcta - venv encontrado en: c:\code\strix-system\venv
# ✅ Directorio de trabajo cambiado a: c:\code\strix-system
#
# 🧪 Verificando imports...
# ✅ health_check - OK
# ✅ PortfolioPipelineProcessor - OK
# ✅ SQLAlchemyUnitOfWork - OK
#
# 🎯 ¡Configuración completada! Ahora puedes ejecutar el resto del notebook.

# %%
# Verificar el health check del sistema antes de ejecutar el pipeline
try:
    from security.services.health_check import health_check
    
    print("🔍 Verificando conexiones del sistema...")
    status = health_check()
    print(f"📊 Estado de conexiones: {status}")
    
    if status.get("postgres") != "OK":
        print("❌ PostgreSQL no está disponible. Verifica la configuración.")
        
    if status.get("s3") != "OK":
        print("❌ S3 no está disponible. Verifica la configuración.")
        
    if status.get("postgres") == "OK" and status.get("s3") == "OK":
        print("✅ Todas las conexiones están operativas. Procediendo con el pipeline.")
        
except ImportError as e:
    print(f"⚠️ No se pudo importar health_check: {e}")
    print("🔄 Continuando sin verificación de conexiones...")
    status = {"postgres": "UNKNOWN", "s3": "UNKNOWN"}
except Exception as e:
    print(f"❌ Error al verificar conexiones: {e}")
    status = {"postgres": "ERROR", "s3": "ERROR"}
# Out:
# 🔍 Verificando conexiones del sistema...
# ✅ Nueva Conexión a PostgreSQL establecida.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 2025-06-23 15:36:25,000 - INFO - ✅ PostgreSQL está operativo.
# 2025-06-23 15:36:25,355 - INFO - ✅ S3 está operativo.
# ✅ Conexión a S3 establecida con éxito.
# 📊 Estado de conexiones: {'postgres': 'OK', 's3': 'OK'}
# ✅ Todas las conexiones están operativas. Procediendo con el pipeline.

# %%
# Importar los módulos necesarios para el pipeline paralelo
try:
    from pipeline.services.portfolio_pipeline_parallel import ParallelPortfolioPipelineProcessor
    print("✅ ParallelPortfolioPipelineProcessor importado correctamente")
    parallel_available = True
except ImportError as e:
    print(f"⚠️ ParallelPortfolioPipelineProcessor no disponible: {e}")
    parallel_available = False
    
    # Fallback al processor original
    try:
        from pipeline.services.portfolio_pipeline import PortfolioPipelineProcessor
        print("✅ PortfolioPipelineProcessor original importado como fallback")
    except ImportError as e:
        print(f"❌ Error importando PortfolioPipelineProcessor: {e}")

try:
    from core.infraestructure.uow.sqlalchemy_uow import SQLAlchemyUnitOfWork
    print("✅ SQLAlchemyUnitOfWork importado correctamente")
except ImportError as e:
    print(f"❌ Error importando SQLAlchemyUnitOfWork: {e}")
    print("⚠️ Puede que necesites instalar el módulo core en modo editable")
    
from datetime import datetime, timedelta
print("✅ datetime importado correctamente")

# Importar módulos adicionales para paralelización
try:
    import psutil
    import concurrent.futures
    import multiprocessing
    print("✅ Módulos de paralelización disponibles")
    parallelization_modules = True
except ImportError as e:
    print(f"⚠️ Módulos de paralelización no disponibles: {e}")
    print("💡 Instala con: pip install psutil")
    parallelization_modules = False

print("\n📦 Estado de importaciones completado")
print(f"   🚀 Procesador paralelo: {'✅' if parallel_available else '❌'}")
print(f"   🔧 Módulos paralelización: {'✅' if parallelization_modules else '❌'}")
# Out:
# ✅ ParallelPortfolioPipelineProcessor importado correctamente
# ✅ SQLAlchemyUnitOfWork importado correctamente
# ✅ datetime importado correctamente
# ✅ Módulos de paralelización disponibles
#
# 📦 Estado de importaciones completado
#    🚀 Procesador paralelo: ✅
#    🔧 Módulos paralelización: ✅

# %%
# Verificar portfolios activos antes de ejecutar el pipeline
print("📋 Verificando portfolios activos en el sistema...")

try:
    if 'SQLAlchemyUnitOfWork' in globals():
        with SQLAlchemyUnitOfWork() as uow:
            active_portfolios = uow.portfolio_domains.get_active_portfolios()
            
        print(f"📊 Portfolios activos encontrados: {len(active_portfolios)}")
        if active_portfolios:
            print(f"🔢 IDs de portfolios activos: {active_portfolios}")
        else:
            print("⚠️ No hay portfolios activos. El pipeline no procesará ningún dato.")
    else:
        print("⚠️ SQLAlchemyUnitOfWork no está disponible, saltando verificación")
        active_portfolios = []
        
except Exception as e:
    print(f"❌ Error al verificar portfolios activos: {e}")
    active_portfolios = []
# Out:
# 📋 Verificando portfolios activos en el sistema...
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 📊 Portfolios activos encontrados: 3
# 🔢 IDs de portfolios activos: [34, 35, 1]

# %%
# Verificar algunos dominios del sistema
print("🌐 Verificando dominios en el sistema...")

try:
    if 'SQLAlchemyUnitOfWork' in globals():
        with SQLAlchemyUnitOfWork() as uow:
            # Obtener algunos dominios de ejemplo
            all_domains = uow.domains.get_all_domains()
            
        print(f"🔢 Total de dominios en el sistema: {len(all_domains)}")
        
        if all_domains:
            print("📝 Primeros 5 dominios:")
            for i, domain in enumerate(all_domains[:5]):
                id_thing_display = domain['id_thing'][:20] + "..." if domain['id_thing'] and len(domain['id_thing']) > 20 else domain['id_thing']
                print(f"   {i+1}. ID: {domain['id']}, Domain: {domain['domain']}, Thing: {id_thing_display}")
        else:
            print("⚠️ No hay dominios en el sistema.")
    else:
        print("⚠️ SQLAlchemyUnitOfWork no está disponible, saltando verificación")
        all_domains = []
        
except Exception as e:
    print(f"❌ Error al verificar dominios: {e}")
    all_domains = []
# Out:
# 🌐 Verificando dominios en el sistema...
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🔢 Total de dominios en el sistema: 2320
# 📝 Primeros 5 dominios:
#    1. ID: 324, Domain: AG393AY, Thing: mrn:thing:vehicle:46...
#    2. ID: 751, Domain: GNW901, Thing: mrn:thing:vehicle:c6...
#    3. ID: 686, Domain: AC881NO, Thing: mrn:thing:vehicle:a0...
#    4. ID: 187, Domain: AF434HM, Thing: mrn:thing:vehicle:eb...
#    5. ID: 622, Domain: AF389CB, Thing: mrn:thing:vehicle:6f...

# %%
# Inicializar el procesador del pipeline (paralelo o estándar)
print("🚀 Inicializando el procesador del pipeline...")

try:
    if parallel_available and parallelization_modules:
        # Usar procesador paralelo
        print("🔧 Inicializando procesador PARALELO...")
        
        # Configurar número de workers (opcional)
        max_workers = None  # Auto-detectar, o especificar número: max_workers = 4
        
        processor = ParallelPortfolioPipelineProcessor(max_workers=max_workers)
        processor_type = "PARALELO"
        
        # Mostrar configuración del sistema
        if parallelization_modules:
            cpu_count = psutil.cpu_count(logical=True)
            memory_gb = psutil.virtual_memory().total / (1024**3)
            print(f"   💻 CPUs detectadas: {cpu_count}")
            print(f"   🧠 RAM disponible: {memory_gb:.1f} GB")
            print(f"   🔧 Workers configurados: {processor.max_workers}")
        
    elif 'PortfolioPipelineProcessor' in globals():
        # Usar procesador estándar como fallback
        print("🔄 Inicializando procesador ESTÁNDAR (fallback)...")
        processor = PortfolioPipelineProcessor()
        processor_type = "ESTÁNDAR"
        
    else:
        print("❌ Ningún procesador disponible")
        processor = None
        processor_type = "NO DISPONIBLE"
    
    if processor is not None:
        print(f"✅ Procesador {processor_type} inicializado correctamente")
        
        # Configurar rango de fechas personalizado
        start_date = datetime(2025, 5, 30).strftime("%Y-%m-%d")
        end_date = datetime(2025, 6, 2).strftime("%Y-%m-%d")
        print(f"📅 Rango de fechas configurado: {start_date} hasta {end_date}")
    else:
        start_date = None
        end_date = None
        
except Exception as e:
    print(f"❌ Error al inicializar el procesador: {e}")
    processor = None
    processor_type = "ERROR"
    start_date = None
    end_date = None
# Out:
# 🚀 Inicializando el procesador del pipeline...
# 🔧 Inicializando procesador PARALELO...
# ✅ Conexión a S3 establecida con éxito.
#    💻 CPUs detectadas: 12
#    🧠 RAM disponible: 15.7 GB
#    🔧 Workers configurados: 8
# ✅ Procesador PARALELO inicializado correctamente
# 📅 Rango de fechas configurado: 2025-05-30 hasta 2025-06-02

# %%
# Ejecutar el pipeline con procesamiento paralelo
print("🔄 Ejecutando el pipeline de portfolio...")
print("=" * 60)

if processor is not None and start_date is not None and end_date is not None:
    try:
        print(f"📅 Procesando eventos desde {start_date} hasta {end_date}")
        print(f"🔧 Tipo de procesador: {processor_type}")
        
        # Determinar método de ejecución
        if hasattr(processor, 'run_pipeline_parallel'):
            # Procesador paralelo - ofrecer opciones
            print("🚀 Ejecutando con procesador PARALELO")
            print("\n🔧 Modos de ejecución disponibles:")
            print("   • thread: ThreadPoolExecutor (recomendado para I/O)")
            print("   • process: ProcessPoolExecutor (para CPU intensivo)")
            print("   • auto: Detecta automáticamente el mejor modo")
            
            # Configurar modo de ejecución
            execution_mode = "auto"  # Cambiar por "thread" o "process" si quieres forzar
            print(f"\n🎯 Modo seleccionado: {execution_mode}")
            print("-" * 40)
            
            # Ejecutar pipeline paralelo
            result = processor.run_pipeline_parallel(
                start_date=start_date,
                end_date=end_date,
                execution_mode=execution_mode
            )
            
        elif hasattr(processor, 'run_pipeline'):
            # Procesador estándar
            print("🔄 Ejecutando con procesador ESTÁNDAR")
            
            # Verificar si acepta parámetros
            import inspect
            sig = inspect.signature(processor.run_pipeline)
            
            if len(sig.parameters) >= 2:
                result = processor.run_pipeline(start_date, end_date)
                print("✅ Pipeline ejecutado con parámetros de fecha")
            else:
                print("⚠️ El método run_pipeline() no acepta parámetros de fecha")
                result = processor.run_pipeline()
        else:
            raise AttributeError("El procesador no tiene método run_pipeline válido")
            
        # Mostrar resultados detallados
        print("=" * 60)
        print("📊 RESULTADO DEL PIPELINE:")
        print(f"✅ Éxito: {result.get('success', False)}")
        print(f"📝 Mensaje: {result.get('message', 'Sin mensaje')}")
        
        # Métricas adicionales para procesador paralelo
        if result.get('total_duration'):
            print(f"⏱️ Tiempo total: {result['total_duration']:.2f} segundos")
        
        if result.get('workers_used'):
            print(f"🔧 Workers utilizados: {result['workers_used']}")
        
        if result.get('portfolios_processed'):
            print(f"📂 Portfolios procesados: {result['portfolios_processed']}")
            print(f"✅ Exitosos: {result.get('successful', 0)}")
            print(f"❌ Fallidos: {result.get('failed', 0)}")
        
        if result.get('estimated_speedup'):
            speedup = result['estimated_speedup']
            print(f"🚀 Speedup estimado: {speedup:.2f}x")
            if speedup > 2:
                print("   🎉 ¡Excelente aceleración!")
            elif speedup > 1.5:
                print("   👍 Buena aceleración")
            else:
                print("   ⚠️ Aceleración limitada (normal para pocos portfolios)")
        
        if result.get('avg_duration_per_portfolio'):
            avg_time = result['avg_duration_per_portfolio']
            print(f"📈 Tiempo promedio por portfolio: {avg_time:.2f}s")
        
        # Estado final
        if result.get('success'):
            print("\n🎉 Pipeline ejecutado exitosamente!")
        else:
            print("\n❌ El pipeline falló")
            
    except Exception as e:
        print("=" * 60)
        print(f"❌ Error durante la ejecución del pipeline: {e}")
        import traceback
        print("🔍 Traceback completo:")
        traceback.print_exc()
        result = {"success": False, "message": f"Error: {e}"}
        
else:
    print("❌ No se puede ejecutar el pipeline - procesador o fechas no inicializados")
    print(f"   Procesador: {processor is not None}")
    print(f"   Start date: {start_date is not None}")
    print(f"   End date: {end_date is not None}")
    result = {"success": False, "message": "Procesador o fechas no disponibles"}

print("=" * 60)
# Out:
# 🔄 Ejecutando el pipeline de portfolio...
# ============================================================
# 📅 Procesando eventos desde 2025-05-30 hasta 2025-06-02
# 🔧 Tipo de procesador: PARALELO
# 🚀 Ejecutando con procesador PARALELO
#
# 🔧 Modos de ejecución disponibles:
#    • thread: ThreadPoolExecutor (recomendado para I/O)
#    • process: ProcessPoolExecutor (para CPU intensivo)
#    • auto: Detecta automáticamente el mejor modo
#
# 🎯 Modo seleccionado: auto
# ----------------------------------------
# 🚀 Iniciando pipeline paralelo (auto)
# 📅 Rango: 2025-05-30 hasta 2025-06-02
# 🔧 Workers configurados: 8
# 🔍 Verificando conexiones...
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 2025-06-23 15:38:31,333 - INFO - ✅ PostgreSQL está operativo.
# 2025-06-23 15:38:31,524 - INFO - ✅ S3 está operativo.
# ✅ Conexión a S3 establecida con éxito.
# 📥 Obteniendo carteras activas...
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 3 carteras encontradas
# 📊 Portfolios distribuidos en 3 lotes
# 🔄 [Worker 1] Procesando Portfolio 34
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🔄 [Worker 2] Procesando Portfolio 35
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🔄 [Worker 3] Procesando Portfolio 1
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53269, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:1784a4fd-f182-46ca-aa85-5fa0adebca63/things/type=mrn:things:vehicle/mrn:thing:vehicle:63c2d92a-d73f-4cb6-a306-05789d213985/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:1784a4fd-f182-46ca-aa85-5fa0adebca63/things/type=mrn:things:vehicle/mrn:thing:vehicle:63c2d92a-d73f-4cb6-a306-05789d213985/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 38, 35, 372562)}
# 🚨 Error registrado en BD: {'id': 53270, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:1784a4fd-f182-46ca-aa85-5fa0adebca63/things/type=mrn:things:vehicle/mrn:thing:vehicle:63c2d92a-d73f-4cb6-a306-05789d213985/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:1784a4fd-f182-46ca-aa85-5fa0adebca63/things/type=mrn:things:vehicle/mrn:thing:vehicle:63c2d92a-d73f-4cb6-a306-05789d213985/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 38, 36, 368148)}
# 🚨 Error registrado en BD: {'id': 53271, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:1784a4fd-f182-46ca-aa85-5fa0adebca63/things/type=mrn:things:vehicle/mrn:thing:vehicle:63c2d92a-d73f-4cb6-a306-05789d213985/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:1784a4fd-f182-46ca-aa85-5fa0adebca63/things/type=mrn:things:vehicle/mrn:thing:vehicle:63c2d92a-d73f-4cb6-a306-05789d213985/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 38, 37, 236506)}
# 🚨 Error registrado en BD: {'id': 53272, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:1784a4fd-f182-46ca-aa85-5fa0adebca63/things/type=mrn:things:vehicle/mrn:thing:vehicle:63c2d92a-d73f-4cb6-a306-05789d213985/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:1784a4fd-f182-46ca-aa85-5fa0adebca63/things/type=mrn:things:vehicle/mrn:thing:vehicle:63c2d92a-d73f-4cb6-a306-05789d213985/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 38, 38, 127415)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 428 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 183 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 927 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53273, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:e75f30b1-1480-4fe8-bd72-151903a66114/things/type=mrn:things:vehicle/mrn:thing:vehicle:36a056d8-8aed-41b2-b504-4b87e88ffcee/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:e75f30b1-1480-4fe8-bd72-151903a66114/things/type=mrn:things:vehicle/mrn:thing:vehicle:36a056d8-8aed-41b2-b504-4b87e88ffcee/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 38, 58, 328450)}
# 🚨 Error registrado en BD: {'id': 53274, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:e75f30b1-1480-4fe8-bd72-151903a66114/things/type=mrn:things:vehicle/mrn:thing:vehicle:36a056d8-8aed-41b2-b504-4b87e88ffcee/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:e75f30b1-1480-4fe8-bd72-151903a66114/things/type=mrn:things:vehicle/mrn:thing:vehicle:36a056d8-8aed-41b2-b504-4b87e88ffcee/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 38, 59, 258968)}
# 🚨 Error registrado en BD: {'id': 53275, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:e75f30b1-1480-4fe8-bd72-151903a66114/things/type=mrn:things:vehicle/mrn:thing:vehicle:36a056d8-8aed-41b2-b504-4b87e88ffcee/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:e75f30b1-1480-4fe8-bd72-151903a66114/things/type=mrn:things:vehicle/mrn:thing:vehicle:36a056d8-8aed-41b2-b504-4b87e88ffcee/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 39, 0, 134014)}
# 🚨 Error registrado en BD: {'id': 53276, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:e75f30b1-1480-4fe8-bd72-151903a66114/things/type=mrn:things:vehicle/mrn:thing:vehicle:36a056d8-8aed-41b2-b504-4b87e88ffcee/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:e75f30b1-1480-4fe8-bd72-151903a66114/things/type=mrn:things:vehicle/mrn:thing:vehicle:36a056d8-8aed-41b2-b504-4b87e88ffcee/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 39, 1, 31180)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 83 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53277, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:69c700ce-fe60-4528-aa10-c92fd9e5c151/things/type=mrn:things:vehicle/mrn:thing:vehicle:d1307a39-06e5-4441-aa67-403bb741eeb2/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:69c700ce-fe60-4528-aa10-c92fd9e5c151/things/type=mrn:things:vehicle/mrn:thing:vehicle:d1307a39-06e5-4441-aa67-403bb741eeb2/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 39, 18, 249514)}
# 🚨 Error registrado en BD: {'id': 53278, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:69c700ce-fe60-4528-aa10-c92fd9e5c151/things/type=mrn:things:vehicle/mrn:thing:vehicle:d1307a39-06e5-4441-aa67-403bb741eeb2/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:69c700ce-fe60-4528-aa10-c92fd9e5c151/things/type=mrn:things:vehicle/mrn:thing:vehicle:d1307a39-06e5-4441-aa67-403bb741eeb2/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 39, 19, 205725)}
# 🚨 Error registrado en BD: {'id': 53279, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:69c700ce-fe60-4528-aa10-c92fd9e5c151/things/type=mrn:things:vehicle/mrn:thing:vehicle:d1307a39-06e5-4441-aa67-403bb741eeb2/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:69c700ce-fe60-4528-aa10-c92fd9e5c151/things/type=mrn:things:vehicle/mrn:thing:vehicle:d1307a39-06e5-4441-aa67-403bb741eeb2/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 39, 20, 69622)}
# ✅ 539 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53280, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:69c700ce-fe60-4528-aa10-c92fd9e5c151/things/type=mrn:things:vehicle/mrn:thing:vehicle:d1307a39-06e5-4441-aa67-403bb741eeb2/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:69c700ce-fe60-4528-aa10-c92fd9e5c151/things/type=mrn:things:vehicle/mrn:thing:vehicle:d1307a39-06e5-4441-aa67-403bb741eeb2/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 39, 20, 938748)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2311 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 340 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 424 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 537 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 244 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 901 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2380 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 576 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 200 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 730 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 355 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 383 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 960 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 210 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 368 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1615 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 623 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 919 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1156 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 929 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1323 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1036 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 94 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 507 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 926 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 396 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 263 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1110 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 873 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2596 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 3194 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 292 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 198 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 760 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 49 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53296, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:4f7137b5-1119-4d46-80d4-20b3df6292b4/things/type=mrn:things:vehicle/mrn:thing:vehicle:fee2bbfc-8695-45c5-9f18-7c9a96762b4f/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:4f7137b5-1119-4d46-80d4-20b3df6292b4/things/type=mrn:things:vehicle/mrn:thing:vehicle:fee2bbfc-8695-45c5-9f18-7c9a96762b4f/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 43, 22, 644108)}
# ✅ 4992 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53297, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:4f7137b5-1119-4d46-80d4-20b3df6292b4/things/type=mrn:things:vehicle/mrn:thing:vehicle:fee2bbfc-8695-45c5-9f18-7c9a96762b4f/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:4f7137b5-1119-4d46-80d4-20b3df6292b4/things/type=mrn:things:vehicle/mrn:thing:vehicle:fee2bbfc-8695-45c5-9f18-7c9a96762b4f/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 43, 23, 542127)}
# 🚨 Error registrado en BD: {'id': 53298, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:4f7137b5-1119-4d46-80d4-20b3df6292b4/things/type=mrn:things:vehicle/mrn:thing:vehicle:fee2bbfc-8695-45c5-9f18-7c9a96762b4f/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:4f7137b5-1119-4d46-80d4-20b3df6292b4/things/type=mrn:things:vehicle/mrn:thing:vehicle:fee2bbfc-8695-45c5-9f18-7c9a96762b4f/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 43, 24, 489864)}
# ✅ 11506 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53299, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:4f7137b5-1119-4d46-80d4-20b3df6292b4/things/type=mrn:things:vehicle/mrn:thing:vehicle:fee2bbfc-8695-45c5-9f18-7c9a96762b4f/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:4f7137b5-1119-4d46-80d4-20b3df6292b4/things/type=mrn:things:vehicle/mrn:thing:vehicle:fee2bbfc-8695-45c5-9f18-7c9a96762b4f/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 43, 26, 45106)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 535 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 778 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 933 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 777 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 451 eventos almacenados en la base de datos.✅ 375 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
#
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 197 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 386 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2121 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 694 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1260 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 3010 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 243 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2823 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 5061 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 322 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 468 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1667 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 555 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 363 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2047 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53329, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:314db765-7ea4-4f41-9c30-e3cef09a4568/things/type=mrn:things:vehicle/mrn:thing:vehicle:4ea28bfd-811e-4dd3-8d37-d841fec2feba/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:314db765-7ea4-4f41-9c30-e3cef09a4568/things/type=mrn:things:vehicle/mrn:thing:vehicle:4ea28bfd-811e-4dd3-8d37-d841fec2feba/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 45, 46, 748990)}
# 🚨 Error registrado en BD: {'id': 53330, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:314db765-7ea4-4f41-9c30-e3cef09a4568/things/type=mrn:things:vehicle/mrn:thing:vehicle:4ea28bfd-811e-4dd3-8d37-d841fec2feba/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:314db765-7ea4-4f41-9c30-e3cef09a4568/things/type=mrn:things:vehicle/mrn:thing:vehicle:4ea28bfd-811e-4dd3-8d37-d841fec2feba/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 45, 48, 312081)}
# 🚨 Error registrado en BD: {'id': 53331, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:314db765-7ea4-4f41-9c30-e3cef09a4568/things/type=mrn:things:vehicle/mrn:thing:vehicle:4ea28bfd-811e-4dd3-8d37-d841fec2feba/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:314db765-7ea4-4f41-9c30-e3cef09a4568/things/type=mrn:things:vehicle/mrn:thing:vehicle:4ea28bfd-811e-4dd3-8d37-d841fec2feba/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 45, 49, 202920)}
# 🚨 Error registrado en BD: {'id': 53332, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:314db765-7ea4-4f41-9c30-e3cef09a4568/things/type=mrn:things:vehicle/mrn:thing:vehicle:4ea28bfd-811e-4dd3-8d37-d841fec2feba/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:314db765-7ea4-4f41-9c30-e3cef09a4568/things/type=mrn:things:vehicle/mrn:thing:vehicle:4ea28bfd-811e-4dd3-8d37-d841fec2feba/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 45, 50, 91599)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1382 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2918 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1110 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53333, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:1f40ac0b-6448-4c6e-9371-0bb6de3caa7e/things/type=mrn:things:vehicle/mrn:thing:vehicle:9571e14e-6f7d-4602-a734-35f9aec4cf2d/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:1f40ac0b-6448-4c6e-9371-0bb6de3caa7e/things/type=mrn:things:vehicle/mrn:thing:vehicle:9571e14e-6f7d-4602-a734-35f9aec4cf2d/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 46, 10, 98621)}
# 🚨 Error registrado en BD: {'id': 53334, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:1f40ac0b-6448-4c6e-9371-0bb6de3caa7e/things/type=mrn:things:vehicle/mrn:thing:vehicle:9571e14e-6f7d-4602-a734-35f9aec4cf2d/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:1f40ac0b-6448-4c6e-9371-0bb6de3caa7e/things/type=mrn:things:vehicle/mrn:thing:vehicle:9571e14e-6f7d-4602-a734-35f9aec4cf2d/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 46, 11, 506935)}
# ✅ 94 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 85 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2734 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 904 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 354 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1516 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2198 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 824 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2543 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53335, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:76bbf5e6-95b7-443f-92fd-0b6de400fd47/things/type=mrn:things:vehicle/mrn:thing:vehicle:f2f72102-c371-4164-979c-e43fd0c189ed/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:76bbf5e6-95b7-443f-92fd-0b6de400fd47/things/type=mrn:things:vehicle/mrn:thing:vehicle:f2f72102-c371-4164-979c-e43fd0c189ed/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 47, 18, 39440)}
# 🚨 Error registrado en BD: {'id': 53336, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:76bbf5e6-95b7-443f-92fd-0b6de400fd47/things/type=mrn:things:vehicle/mrn:thing:vehicle:f2f72102-c371-4164-979c-e43fd0c189ed/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:76bbf5e6-95b7-443f-92fd-0b6de400fd47/things/type=mrn:things:vehicle/mrn:thing:vehicle:f2f72102-c371-4164-979c-e43fd0c189ed/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 47, 19, 611828)}
# ✅ 285 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53337, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:6d9c66d0-6ae6-4abc-bcba-325a1ccd7ca5/things/type=mrn:things:vehicle/mrn:thing:vehicle:ac27d377-a285-44ab-af00-b8661b466d7b/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:6d9c66d0-6ae6-4abc-bcba-325a1ccd7ca5/things/type=mrn:things:vehicle/mrn:thing:vehicle:ac27d377-a285-44ab-af00-b8661b466d7b/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 47, 33, 14134)}
# ⚠ No hay eventos nuevos para almacenar.
# 🚨 Error registrado en BD: {'id': 53338, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:6d9c66d0-6ae6-4abc-bcba-325a1ccd7ca5/things/type=mrn:things:vehicle/mrn:thing:vehicle:ac27d377-a285-44ab-af00-b8661b466d7b/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:6d9c66d0-6ae6-4abc-bcba-325a1ccd7ca5/things/type=mrn:things:vehicle/mrn:thing:vehicle:ac27d377-a285-44ab-af00-b8661b466d7b/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 47, 33, 972284)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53339, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:6d9c66d0-6ae6-4abc-bcba-325a1ccd7ca5/things/type=mrn:things:vehicle/mrn:thing:vehicle:ac27d377-a285-44ab-af00-b8661b466d7b/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:6d9c66d0-6ae6-4abc-bcba-325a1ccd7ca5/things/type=mrn:things:vehicle/mrn:thing:vehicle:ac27d377-a285-44ab-af00-b8661b466d7b/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 47, 34, 851131)}
# 🚨 Error registrado en BD: {'id': 53340, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:6d9c66d0-6ae6-4abc-bcba-325a1ccd7ca5/things/type=mrn:things:vehicle/mrn:thing:vehicle:ac27d377-a285-44ab-af00-b8661b466d7b/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:6d9c66d0-6ae6-4abc-bcba-325a1ccd7ca5/things/type=mrn:things:vehicle/mrn:thing:vehicle:ac27d377-a285-44ab-af00-b8661b466d7b/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 47, 36, 339946)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 11883 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1397 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 537 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 353 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 680 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 4079 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53341, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:96f5d021-1181-42d1-b065-1c78763be9f9/things/type=mrn:things:vehicle/mrn:thing:vehicle:44d440ca-76be-460b-b84b-688706b6d981/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:96f5d021-1181-42d1-b065-1c78763be9f9/things/type=mrn:things:vehicle/mrn:thing:vehicle:44d440ca-76be-460b-b84b-688706b6d981/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 48, 16, 947496)}
# 🚨 Error registrado en BD: {'id': 53342, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:96f5d021-1181-42d1-b065-1c78763be9f9/things/type=mrn:things:vehicle/mrn:thing:vehicle:44d440ca-76be-460b-b84b-688706b6d981/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:96f5d021-1181-42d1-b065-1c78763be9f9/things/type=mrn:things:vehicle/mrn:thing:vehicle:44d440ca-76be-460b-b84b-688706b6d981/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 48, 17, 849127)}
# 🚨 Error registrado en BD: {'id': 53343, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:96f5d021-1181-42d1-b065-1c78763be9f9/things/type=mrn:things:vehicle/mrn:thing:vehicle:44d440ca-76be-460b-b84b-688706b6d981/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:96f5d021-1181-42d1-b065-1c78763be9f9/things/type=mrn:things:vehicle/mrn:thing:vehicle:44d440ca-76be-460b-b84b-688706b6d981/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 48, 18, 726129)}
# 🚨 Error registrado en BD: {'id': 53344, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:96f5d021-1181-42d1-b065-1c78763be9f9/things/type=mrn:things:vehicle/mrn:thing:vehicle:44d440ca-76be-460b-b84b-688706b6d981/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:96f5d021-1181-42d1-b065-1c78763be9f9/things/type=mrn:things:vehicle/mrn:thing:vehicle:44d440ca-76be-460b-b84b-688706b6d981/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 48, 19, 601781)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1002 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 4603 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 11945 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53345, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:2fb25c73-1be2-4e18-bf12-893a3ab48de9/things/type=mrn:things:vehicle/mrn:thing:vehicle:a523cf61-9495-42f8-9281-6ba3b5ec4f18/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:2fb25c73-1be2-4e18-bf12-893a3ab48de9/things/type=mrn:things:vehicle/mrn:thing:vehicle:a523cf61-9495-42f8-9281-6ba3b5ec4f18/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 48, 53, 410544)}
# 🚨 Error registrado en BD: {'id': 53346, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:2fb25c73-1be2-4e18-bf12-893a3ab48de9/things/type=mrn:things:vehicle/mrn:thing:vehicle:a523cf61-9495-42f8-9281-6ba3b5ec4f18/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:2fb25c73-1be2-4e18-bf12-893a3ab48de9/things/type=mrn:things:vehicle/mrn:thing:vehicle:a523cf61-9495-42f8-9281-6ba3b5ec4f18/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 48, 54, 333093)}
# ✅ 947 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53347, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:2fb25c73-1be2-4e18-bf12-893a3ab48de9/things/type=mrn:things:vehicle/mrn:thing:vehicle:a523cf61-9495-42f8-9281-6ba3b5ec4f18/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:2fb25c73-1be2-4e18-bf12-893a3ab48de9/things/type=mrn:things:vehicle/mrn:thing:vehicle:a523cf61-9495-42f8-9281-6ba3b5ec4f18/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 48, 55, 238228)}
# ✅ 141 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 150 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1701 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 168 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 623 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1716 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 674 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1102 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 162 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1176 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 3510 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2356 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 530 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 507 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 563 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53362, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:4d5950f0-4ea2-469b-bf8f-a7f9460be99b/things/type=mrn:things:vehicle/mrn:thing:vehicle:5357933e-2c0a-4d7f-b124-5e2af7ffe961/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:4d5950f0-4ea2-469b-bf8f-a7f9460be99b/things/type=mrn:things:vehicle/mrn:thing:vehicle:5357933e-2c0a-4d7f-b124-5e2af7ffe961/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 50, 38, 286830)}
# 🚨 Error registrado en BD: {'id': 53363, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:4d5950f0-4ea2-469b-bf8f-a7f9460be99b/things/type=mrn:things:vehicle/mrn:thing:vehicle:5357933e-2c0a-4d7f-b124-5e2af7ffe961/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:4d5950f0-4ea2-469b-bf8f-a7f9460be99b/things/type=mrn:things:vehicle/mrn:thing:vehicle:5357933e-2c0a-4d7f-b124-5e2af7ffe961/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 50, 39, 184130)}
# 🚨 Error registrado en BD: {'id': 53364, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:4d5950f0-4ea2-469b-bf8f-a7f9460be99b/things/type=mrn:things:vehicle/mrn:thing:vehicle:5357933e-2c0a-4d7f-b124-5e2af7ffe961/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:4d5950f0-4ea2-469b-bf8f-a7f9460be99b/things/type=mrn:things:vehicle/mrn:thing:vehicle:5357933e-2c0a-4d7f-b124-5e2af7ffe961/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 50, 40, 69777)}
# 🚨 Error registrado en BD: {'id': 53365, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:4d5950f0-4ea2-469b-bf8f-a7f9460be99b/things/type=mrn:things:vehicle/mrn:thing:vehicle:5357933e-2c0a-4d7f-b124-5e2af7ffe961/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:4d5950f0-4ea2-469b-bf8f-a7f9460be99b/things/type=mrn:things:vehicle/mrn:thing:vehicle:5357933e-2c0a-4d7f-b124-5e2af7ffe961/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 50, 41, 17886)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 191 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53366, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:958a5de8-f63f-43b4-94f2-7ed66320345b/things/type=mrn:things:vehicle/mrn:thing:vehicle:179d5356-5be4-4a6b-b63a-a83066b2973d/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:958a5de8-f63f-43b4-94f2-7ed66320345b/things/type=mrn:things:vehicle/mrn:thing:vehicle:179d5356-5be4-4a6b-b63a-a83066b2973d/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 50, 59, 310975)}
# ✅ 782 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2733 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 98 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 328 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 98 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 231 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 6961 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2024 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 994 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1126 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 276 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 910 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1606 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53395, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:e3fd386d-8f6e-43a9-bdcc-3cf264e86fef/things/type=mrn:things:vehicle/mrn:thing:vehicle:dede47d3-5a79-4b24-b01d-07af24f31860/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:e3fd386d-8f6e-43a9-bdcc-3cf264e86fef/things/type=mrn:things:vehicle/mrn:thing:vehicle:dede47d3-5a79-4b24-b01d-07af24f31860/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 52, 29, 46988)}
# 🚨 Error registrado en BD: {'id': 53396, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:e3fd386d-8f6e-43a9-bdcc-3cf264e86fef/things/type=mrn:things:vehicle/mrn:thing:vehicle:dede47d3-5a79-4b24-b01d-07af24f31860/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:e3fd386d-8f6e-43a9-bdcc-3cf264e86fef/things/type=mrn:things:vehicle/mrn:thing:vehicle:dede47d3-5a79-4b24-b01d-07af24f31860/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 52, 29, 917053)}
# 🚨 Error registrado en BD: {'id': 53397, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:e3fd386d-8f6e-43a9-bdcc-3cf264e86fef/things/type=mrn:things:vehicle/mrn:thing:vehicle:dede47d3-5a79-4b24-b01d-07af24f31860/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:e3fd386d-8f6e-43a9-bdcc-3cf264e86fef/things/type=mrn:things:vehicle/mrn:thing:vehicle:dede47d3-5a79-4b24-b01d-07af24f31860/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 52, 30, 826299)}
# ✅ 346 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 450 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 246 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1015 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1776 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 304 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 128 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1510 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 361 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 56 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1640 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2428 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 444 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 47 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1138 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 384 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 316 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2515 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1070 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 535 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2245 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 607 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 964 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1930 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 209 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 425 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 856 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 89 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 519 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 700 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53428, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:a779729d-8901-4937-a097-50ed1b7dcc24/things/type=mrn:things:vehicle/mrn:thing:vehicle:fe7cdbc0-cb99-40b1-bc6e-043c0e4983e9/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:a779729d-8901-4937-a097-50ed1b7dcc24/things/type=mrn:things:vehicle/mrn:thing:vehicle:fe7cdbc0-cb99-40b1-bc6e-043c0e4983e9/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 55, 53, 848387)}
# ✅ 504 eventos almacenados en la base de datos.✅ 128 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
#
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 984 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53429, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:778fc28e-b796-4152-a7bb-a7a7e17b9625/things/type=mrn:things:vehicle/mrn:thing:vehicle:6cd8289a-3562-4d91-9d29-f991a01cf652/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:778fc28e-b796-4152-a7bb-a7a7e17b9625/things/type=mrn:things:vehicle/mrn:thing:vehicle:6cd8289a-3562-4d91-9d29-f991a01cf652/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 56, 12, 899258)}
# 🚨 Error registrado en BD: {'id': 53430, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:778fc28e-b796-4152-a7bb-a7a7e17b9625/things/type=mrn:things:vehicle/mrn:thing:vehicle:6cd8289a-3562-4d91-9d29-f991a01cf652/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:778fc28e-b796-4152-a7bb-a7a7e17b9625/things/type=mrn:things:vehicle/mrn:thing:vehicle:6cd8289a-3562-4d91-9d29-f991a01cf652/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 18, 56, 13, 771310)}
# ✅ 697 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 257 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 11874 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1119 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2039 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 548 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 276 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 415 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 770 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 791 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 588 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2347 eventos almacenados en la base de datos.
# ...
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 522 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 895 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 314 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1727 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 997 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 873 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 446 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 791 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 12042 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 63 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 392 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 3996 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 46 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1105 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1516 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 189 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 271 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1917 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 821 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 760 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1318 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1214 eventos almacenados en la base de datos.✅ 758 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
#
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1037 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53824, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:2f67291b-4112-4674-881a-bb14d5789ff8/things/type=mrn:things:vehicle/mrn:thing:vehicle:4a256daa-8684-4dd2-a767-1d0e51e4b45b/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:2f67291b-4112-4674-881a-bb14d5789ff8/things/type=mrn:things:vehicle/mrn:thing:vehicle:4a256daa-8684-4dd2-a767-1d0e51e4b45b/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 19, 28, 24, 18503)}
# ✅ 246 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 646 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1280 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 724 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1049 eventos almacenados en la base de datos.✅ 748 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
#
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 361 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2217 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 940 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 61 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 444 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 11749 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 48 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 356 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 376 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 48 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 489 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53857, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:dd4f38ad-4844-40dd-a0a4-af7c38be0d04/things/type=mrn:things:vehicle/mrn:thing:vehicle:22829d52-f330-4ad4-a8d5-72f25c12a817/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:dd4f38ad-4844-40dd-a0a4-af7c38be0d04/things/type=mrn:things:vehicle/mrn:thing:vehicle:22829d52-f330-4ad4-a8d5-72f25c12a817/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 19, 35, 44, 877431)}
# 🚨 Error registrado en BD: {'id': 53858, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:dd4f38ad-4844-40dd-a0a4-af7c38be0d04/things/type=mrn:things:vehicle/mrn:thing:vehicle:22829d52-f330-4ad4-a8d5-72f25c12a817/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:dd4f38ad-4844-40dd-a0a4-af7c38be0d04/things/type=mrn:things:vehicle/mrn:thing:vehicle:22829d52-f330-4ad4-a8d5-72f25c12a817/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 19, 35, 47, 439189)}
# 🚨 Error registrado en BD: {'id': 53859, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:dd4f38ad-4844-40dd-a0a4-af7c38be0d04/things/type=mrn:things:vehicle/mrn:thing:vehicle:22829d52-f330-4ad4-a8d5-72f25c12a817/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:dd4f38ad-4844-40dd-a0a4-af7c38be0d04/things/type=mrn:things:vehicle/mrn:thing:vehicle:22829d52-f330-4ad4-a8d5-72f25c12a817/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 19, 35, 48, 810278)}
# 🚨 Error registrado en BD: {'id': 53860, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:dd4f38ad-4844-40dd-a0a4-af7c38be0d04/things/type=mrn:things:vehicle/mrn:thing:vehicle:22829d52-f330-4ad4-a8d5-72f25c12a817/signals/date=2025-06/2025-06-02_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:dd4f38ad-4844-40dd-a0a4-af7c38be0d04/things/type=mrn:things:vehicle/mrn:thing:vehicle:22829d52-f330-4ad4-a8d5-72f25c12a817/signals/date=2025-06/2025-06-02_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 19, 35, 50, 308346)}
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 371 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 486 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1302 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 49 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 140 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 782 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 287 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1557 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 11801 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 48 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1483 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1901 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 196 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 657 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 3307 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 550 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1739 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 3182 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 512 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 788 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1853 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 811 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2955 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 5729 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 55 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1629 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1079 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 659 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1237 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 838 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1435 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 11511 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 195 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1151 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 287 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1832 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2306 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1177 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 98 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53890, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:506969cf-22d2-402f-95fd-5a770193497a/things/type=mrn:things:vehicle/mrn:thing:vehicle:a6bb7a5f-fcf0-4d54-9adf-3014e389130c/signals/date=2025-05/2025-05-30_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:506969cf-22d2-402f-95fd-5a770193497a/things/type=mrn:things:vehicle/mrn:thing:vehicle:a6bb7a5f-fcf0-4d54-9adf-3014e389130c/signals/date=2025-05/2025-05-30_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 20, 24, 14, 904284)}
# ✅ 890 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 950 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 532 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 571 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 426 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1180 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 5008 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 218 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 98 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 960 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 290 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 710 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 798 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 414 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 586 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 3556 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 96 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 416 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 1282 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# 🚨 Error registrado en BD: {'id': 53923, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:c10b0c6d-2112-416a-a02a-abfd7b6256fe/things/type=mrn:things:vehicle/mrn:thing:vehicle:fc0c3a53-5259-483a-a17a-d5969272c0a8/signals/date=2025-05/2025-05-31_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:c10b0c6d-2112-416a-a02a-abfd7b6256fe/things/type=mrn:things:vehicle/mrn:thing:vehicle:fc0c3a53-5259-483a-a17a-d5969272c0a8/signals/date=2025-05/2025-05-31_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 20, 42, 25, 581789)}
# 🚨 Error registrado en BD: {'id': 53924, 'method': 'retrieve_and_store_events', 'error_type': 'NoSuchKey', 'message': 'Error al procesar ar/magenta/mrn:account:c10b0c6d-2112-416a-a02a-abfd7b6256fe/things/type=mrn:things:vehicle/mrn:thing:vehicle:fc0c3a53-5259-483a-a17a-d5969272c0a8/signals/date=2025-06/2025-06-01_dataset.avro: The specified key does not exist.', 'bucket': 'strix-consumer-raw-prod', 's3_key': 'ar/magenta/mrn:account:c10b0c6d-2112-416a-a02a-abfd7b6256fe/things/type=mrn:things:vehicle/mrn:thing:vehicle:fc0c3a53-5259-483a-a17a-d5969272c0a8/signals/date=2025-06/2025-06-01_dataset.avro', 'created_at': datetime.datetime(2025, 6, 23, 20, 42, 26, 539174)}
# ✅ 97 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 913 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 135 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 747 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy
# ✅ 2027 eventos almacenados en la base de datos.
# 🚨 ENTER: Se abrió una nueva conexión SQLAlchemy

# %%
# Verificar algunos eventos procesados (opcional)
print("🔍 Verificando eventos procesados...")

try:
    with SQLAlchemyUnitOfWork() as uow:
        # Contar eventos en el rango de fechas procesado
        from datetime import datetime
        start_timestamp = int(datetime(2025, 4, 1).timestamp() * 1000)
        end_timestamp = int(datetime(2025, 4, 30).timestamp() * 1000)
        
        # Obtener algunos eventos de ejemplo de un dominio específico
        if active_portfolios:
            domain_ids = uow.portfolio_domains.get_domains_by_portfolio(active_portfolios[0])
            if domain_ids:
                sample_domain = domain_ids[0]
                events = uow.events.get_events_by_domain_and_date(
                    sample_domain, 
                    datetime(2025, 4, 1), 
                    datetime(2025, 4, 2)
                )
                print(f"📊 Eventos encontrados para dominio {sample_domain}: {len(events)}")
                
                if events:
                    print("📝 Primer evento:")
                    first_event = events[0]
                    print(f"   ID: {first_event['id']}")
                    print(f"   Coordenadas: ({first_event['latitude']}, {first_event['longitude']})")
                    print(f"   Velocidad: {first_event['speed']} km/h")
                    print(f"   Timestamp: {first_event['timestamp']}")
            else:
                print("⚠️ No se encontraron dominios para el portfolio activo")
        else:
            print("⚠️ No hay portfolios activos para verificar eventos")
            
except Exception as e:
    print(f"❌ Error al verificar eventos: {e}")

# %%
# Test manual adicional - verificar servicios individuales
print("🧪 Ejecutando tests adicionales de componentes...")

# Test del servicio de portfolio
try:
    from core.services.portfolio_service import PortfolioService
    portfolio_service = PortfolioService()
    
    portfolios = portfolio_service.get_all_portfolios()
    print(f"✅ Servicio de Portfolio: {len(portfolios)} portfolios encontrados")
except Exception as e:
    print(f"❌ Error en Servicio de Portfolio: {e}")

# Test del servicio de dominios
try:
    from core.services.domain_service import DomainService
    domain_service = DomainService()
    
    domains = domain_service.get_all_domains()
    print(f"✅ Servicio de Dominios: {len(domains)} dominios encontrados")
except Exception as e:
    print(f"❌ Error en Servicio de Dominios: {e}")

# Test del servicio S3
try:
    from core.services.s3_event_service import S3EventService
    s3_service = S3EventService()
    
    if s3_service.s3_client:
        print("✅ Servicio S3: Conexión establecida")
    else:
        print("❌ Servicio S3: No se pudo establecer conexión")
except Exception as e:
    print(f"❌ Error en Servicio S3: {e}")

# Información de configuración actual
print("\n🔧 Información del entorno:")
print(f"📁 Directorio de trabajo: {os.getcwd()}")
print(f"🐍 Python executable: {sys.executable}")
print(f"📦 Módulos en sys.path: {len(sys.path)} rutas configuradas")

# %%
# Resumen final
print("\n" + "=" * 60)
print("📋 RESUMEN FINAL DEL TEST")
print("=" * 60)
print(f"🔧 Sistema: Strix Portfolio Pipeline")
print(f"🚀 Tipo de procesador: {processor_type if 'processor_type' in locals() else 'No disponible'}")
print(f"📅 Fecha de ejecución: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
if 'start_date' in locals() and start_date:
    print(f"🌐 Rango procesado: {start_date} a {end_date}")
if 'status' in locals():
    print(f"📊 Estado de conexiones: PostgreSQL={status.get('postgres', 'UNKNOWN')}, S3={status.get('s3', 'UNKNOWN')}")
if 'active_portfolios' in locals():
    print(f"📁 Portfolios activos: {len(active_portfolios)}")
if 'all_domains' in locals():
    print(f"🌍 Total dominios: {len(all_domains)}")
    
# Información del pipeline ejecutado
if 'result' in locals():
    print(f"✅ Pipeline completado: {result.get('success', 'No ejecutado')}")
    if result.get('total_duration'):
        print(f"⏱️ Duración total: {result['total_duration']:.2f} segundos")
    if result.get('workers_used'):
        print(f"🔧 Workers paralelos: {result['workers_used']}")
    if result.get('estimated_speedup'):
        print(f"🚀 Aceleración lograda: {result['estimated_speedup']:.2f}x")
    if result.get('portfolios_processed'):
        success_rate = (result.get('successful', 0) / result['portfolios_processed']) * 100
        print(f"📈 Tasa de éxito: {success_rate:.1f}% ({result.get('successful', 0)}/{result['portfolios_processed']})")
else:
    print(f"❌ Pipeline: No ejecutado")

# Recomendaciones
print("\n💡 RECOMENDACIONES:")
if 'parallel_available' in locals() and parallel_available:
    print("   ✅ Procesador paralelo funcionando correctamente")
    if 'result' in locals() and result.get('estimated_speedup', 0) < 1.5:
        print("   💭 Para mayor speedup, procesa más portfolios o aumenta workers")
else:
    print("   ⚠️ Considera crear el archivo portfolio_pipeline_parallel.py para mejor rendimiento")
    
if 'parallelization_modules' in locals() and not parallelization_modules:
    print("   📦 Instala psutil para métricas del sistema: pip install psutil")

print("=" * 60)
print("🎯 Test del Portfolio Pipeline completado")

# Información adicional para debugging
if 'result' in locals() and not result.get('success', False):
    print("\n🔍 INFORMACIÓN DE DEBUG:")
    print(f"   📁 Directorio actual: {os.getcwd()}")
    print(f"   🐍 Python: {sys.executable}")
    print(f"   📦 Módulos importados: {', '.join([k for k in globals().keys() if not k.startswith('_')][:10])}...")
